# %% [markdown]
# ## Predicción de precios de casas con Redes Neuronales
# ### Objetivo
# Predecir el valor de un producto dado un historico de precios.
#
# ### Integrantes:
#
# - Nery Fuentes - 15004337
# - Luis Barreno - 24007314

# %% [markdown]
# ### Importación de librerias

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# %% [markdown]
# ### Carga de datos

# %%
df = pd.read_excel("HousePricePrediction.xlsx")

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0   0          60       RL     8450    Inside     1Fam            5
# 1   1          20       RL     9600       FR2     1Fam            8
# 2   2          60       RL    11250    Inside     1Fam            5
# 3   3          70       RL     9550    Corner     1Fam            5
# 4   4          60       RL    14260       FR2     1Fam            5
#
#    YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0       2003          2003     VinylSd         0.0        856.0   208500.0
# 1       1976          1976     MetalSd         0.0       1262.0   181500.0
# 2       2001          2002     VinylSd         0.0        920.0   223500.0
# 3       1915          1970     Wd Sdng         0.0        756.0   140000.0
# 4       2000          2000     VinylSd         0.0       1145.0   250000.0

# %%
df=df.dropna()

# %%
# Separar características y etiquetas
y_column="SalePrice"

X = df.drop(columns=[y_column])
y = df[y_column]

# %% [markdown]
# ### Normalizar datos

# %%
# Codificar variables categóricas
categorical_columns = ['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st']
encoder = OneHotEncoder(sparse_output=False, drop='first')
X_encoded = pd.DataFrame(encoder.fit_transform(X[categorical_columns]), columns=encoder.get_feature_names_out())
X = pd.concat([X.drop(columns=categorical_columns), X_encoded], axis=1)

# Escalar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Dividir en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
print(X_train)
# Out:
# [[ 1.41341051  2.41970004 -1.01312116 ... -0.40481551 -0.13985672
#   -0.01851217]
#  [ 0.29668566 -0.87361603 -0.33835076 ... -0.40481551 -0.13985672
#   -0.01851217]
#  [-0.70017817  0.06733141 -0.02918139 ... -0.40481551 -0.13985672
#   -0.01851217]
#  ...
#  [-0.39043833 -0.16790545 -0.2997997  ... -0.40481551  7.15017482
#   -0.01851217]
#  [-0.19581254 -0.87361603 -0.25313262 ... -0.40481551  7.15017482
#   -0.01851217]
#  [-0.71085885 -0.16790545 -0.32034336 ...  2.47026108 -0.13985672
#   -0.01851217]]

# %% [markdown]
# ### Crear y entrenar el modelo

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

# Definición del modelo
model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(1)
])

# Configurar optimizador
optimizer = Adam(learning_rate=0.001)

# Compilar modelo
model.compile(
    optimizer=optimizer,
    loss=MeanSquaredError(),
    metrics=[MeanAbsoluteError()]
)

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Entrenamiento
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 39242706944.0000 - mean_absolute_error: 181313.3125 - val_loss: 37830627328.0000 - val_mean_absolute_error: 181070.6875
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39068323840.0000 - mean_absolute_error: 181710.1250 - val_loss: 37732634624.0000 - val_mean_absolute_error: 180813.8594
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38987104256.0000 - mean_absolute_error: 180630.9688 - val_loss: 37256880128.0000 - val_mean_absolute_error: 179604.9531
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36885884928.0000 - mean_absolute_error: 177021.6562 - val_loss: 35734155264.0000 - val_mean_absolute_error: 175769.1250
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36829687808.0000 - mean_absolute_error: 176375.8750 - val_loss: 32097015808.0000 - val_mean_absolute_error: 166346.7031
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31316791296.0000 - mean_absolute_error: 162065.2031 - val_loss: 25535162368.0000 - val_mean_absolute_error: 147710.0781
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2222107392.0000 - mean_absolute_error: 31302.3945 - val_loss: 2030615168.0000 - val_mean_absolute_error: 30946.8828
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1943790976.0000 - mean_absolute_error: 29703.6699 - val_loss: 2036456576.0000 - val_mean_absolute_error: 30974.4902
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2171107584.0000 - mean_absolute_error: 29793.8906 - val_loss: 2037751552.0000 - val_mean_absolute_error: 30889.5703
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1776471168.0000 - mean_absolute_error: 28428.4238 - val_loss: 2037821312.0000 - val_mean_absolute_error: 30892.5605
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2005628544.0000 - mean_absolute_error: 30378.0078 - val_loss: 2029353216.0000 - val_mean_absolute_error: 30782.4141
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2334501888.0000 - mean_absolute_error: 30261.4121 - val_loss: 2034014208.0000 - val_mean_absolute_error: 30611.8711
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1712216448.0000 - mean_absolute_error: 27916.0195 - val_loss: 2039462784.0000 - val_mean_absolute_error: 30686.9824
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1718338560.0000 - mean_absolute_error: 28850.0996 - val_loss: 2038602496.0000 - val_mean_absolute_error: 30839.6406
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1815097728.0000 - mean_absolute_error: 28902.4824 - val_loss: 2034694144.0000 - val_mean_absolute_error: 30699.1660
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2013233408.0000 - mean_absolute_error: 29843.8066 - val_loss: 2038239872.0000 - val_mean_absolute_error: 30609.9805
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1582942080.0000 - mean_absolute_error: 28009.0039 - val_loss: 2024279424.0000 - val_mean_absolute_error: 30590.0078
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1517585152.0000 - mean_absolute_error: 27708.9824 - val_loss: 2024130944.0000 - val_mean_absolute_error: 30513.2695
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2255358464.0000 - mean_absolute_error: 30929.8555 - val_loss: 2025828224.0000 - val_mean_absolute_error: 30608.2734
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1845488768.0000 - mean_absolute_error: 27962.5684 - val_loss: 2027769600.0000 - val_mean_absolute_error: 30585.4180
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1891693056.0000 - mean_absolute_error: 28239.9316 - val_loss: 2025073408.0000 - val_mean_absolute_error: 30442.2461
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1582910848.0000 - mean_absolute_error: 28176.5020 - val_loss: 2008543872.0000 - val_mean_absolute_error: 30572.0957
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2205265920.0000 - mean_absolute_error: 29450.0742 - val_loss: 2033268864.0000 - val_mean_absolute_error: 30479.7188
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1939777792.0000 - mean_absolute_error: 29222.6992 - val_loss: 2022088064.0000 - val_mean_absolute_error: 30248.0859
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1785752960.0000 - mean_absolute_error: 27970.8848 - val_loss: 2009764096.0000 - val_mean_absolute_error: 30222.1113
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1768091776.0000 - mean_absolute_error: 27963.6816 - val_loss: 2009835264.0000 - val_mean_absolute_error: 30129.4688
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1659108992.0000 - mean_absolute_error: 27603.0254 - val_loss: 2008874624.0000 - val_mean_absolute_error: 30196.8613
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1949665920.0000 - mean_absolute_error: 29155.3340 - val_loss: 2016314368.0000 - val_mean_absolute_error: 30210.8789
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1831829248.0000 - mean_absolute_error: 28665.5273 - val_loss: 2013289472.0000 - val_mean_absolute_error: 30023.7090
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1522216064.0000 - mean_absolute_error: 27392.2637 - val_loss: 2000323712.0000 - val_mean_absolute_error: 30213.3770
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1899154560.0000 - mean_absolute_error: 28418.0371 - val_loss: 1999713792.0000 - val_mean_absolute_error: 30085.8047
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1735433728.0000 - mean_absolute_error: 27619.6250 - val_loss: 1998019328.0000 - val_mean_absolute_error: 30027.5215
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1854058624.0000 - mean_absolute_error: 28082.7832 - val_loss: 1992276224.0000 - val_mean_absolute_error: 30033.4785
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1950875520.0000 - mean_absolute_error: 30031.8633 - val_loss: 1976371456.0000 - val_mean_absolute_error: 29877.3945
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1680559616.0000 - mean_absolute_error: 27597.6914 - val_loss: 1980859008.0000 - val_mean_absolute_error: 30162.0352
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1487853824.0000 - mean_absolute_error: 27593.4570 - val_loss: 1970714368.0000 - val_mean_absolute_error: 30015.5156
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1843972992.0000 - mean_absolute_error: 29423.7344 - val_loss: 1988747008.0000 - val_mean_absolute_error: 29947.6309
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2279199488.0000 - mean_absolute_error: 29947.8730 - val_loss: 1980968448.0000 - val_mean_absolute_error: 29960.9238
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1601729024.0000 - mean_absolute_error: 27828.9844 - val_loss: 1985320320.0000 - val_mean_absolute_error: 29723.4609
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1813961984.0000 - mean_absolute_error: 27192.6465 - val_loss: 1978172800.0000 - val_mean_absolute_error: 29615.2598
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1822548224.0000 - mean_absolute_error: 28682.8770 - val_loss: 1971503616.0000 - val_mean_absolute_error: 29671.7402
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1549466880.0000 - mean_absolute_error: 26430.6348 - val_loss: 1966669824.0000 - val_mean_absolute_error: 29481.9395
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1872478976.0000 - mean_absolute_error: 28415.9082 - val_loss: 1971855488.0000 - val_mean_absolute_error: 29511.5098
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1890784256.0000 - mean_absolute_error: 28461.9141 - val_loss: 1976285696.0000 - val_mean_absolute_error: 29677.3574
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1874102784.0000 - mean_absolute_error: 27969.0293 - val_loss: 1979637120.0000 - val_mean_absolute_error: 29676.6230
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1523548672.0000 - mean_absolute_error: 26173.5273 - val_loss: 1954122368.0000 - val_mean_absolute_error: 29432.1445
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1655477632.0000 - mean_absolute_error: 27748.6504 - val_loss: 1970705920.0000 - val_mean_absolute_error: 29567.0312
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1561538944.0000 - mean_absolute_error: 27531.6484 - val_loss: 1958947584.0000 - val_mean_absolute_error: 29586.8730

# %% [markdown]
# ### Evaluación del modelo

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# Realizar predicciones en el conjunto de prueba
y_pred = model.predict(X_test)
# Calcular métricas
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)

print(f"Métricas del modelo en el conjunto de prueba:")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
r2 = r2_score(y_test, y_pred)
print(f"R^2: {r2:.2f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Métricas del modelo en el conjunto de prueba:
# Mean Squared Error (MSE): 2666866168.39
# Root Mean Squared Error (RMSE): 51641.71
# Mean Absolute Error (MAE): 31636.53
# R^2: 0.65

# %% [markdown]
# ### Guardar modelo

# %%
# Guardar el modelo y el escalador
model.save('house_price_model.h5')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(encoder, 'encoder.pkl')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['encoder.pkl']

# %%
from sklearn.compose import ColumnTransformer

# Crear el ColumnTransformer para las columnas categóricas
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first'), ['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st'])
    ],
    remainder='passthrough'  # Deja las demás columnas sin cambios
)

# Ajustar y transformar las características de entrenamiento
#X_train_processed = preprocessor.fit_transform(X_train)

# Guardar el preprocesador para usarlo en Flask
joblib.dump(preprocessor, 'preprocessor.pkl')
# Out:
# ['preprocessor.pkl']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
